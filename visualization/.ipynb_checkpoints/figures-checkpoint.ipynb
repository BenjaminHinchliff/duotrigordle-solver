# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("stats.csv")
df
# Out:
#    Game Mode Challenge        Id  Guesses  Time (ms)  Solve Assist
# 0   practice    normal  40606272       33      18668         False
# 1   practice    normal  40606293       34      19527         False
# 2   practice    normal  40606313       34      19631         False
# 3   practice    normal  40606334       33      18211         False
# 4   practice    normal  40606354       33      18186         False
# 5   practice    normal  40606373       33      18207         False
# 6   practice    normal  40606392       34      20829         False
# 7   practice    normal  40606415       35      21794         False
# 8   practice    normal  40606438       34      19925         False
# 9   practice    normal  40606459       34      20008         False
# 10  practice    normal  40606480       33      18898         False
# 11  practice    normal  40606501       34      19595         False
# 12  practice    normal  40606522       34      19425         False
# 13  practice    normal  40606542       34      19594         False
# 14  practice    normal  40606563       34      19645         False
# 15  practice    normal  40606584       34      19487         False
# 16  practice    normal  40606605       34      20288         False
# 17  practice    normal  40606626       34      19742         False
# 18  practice    normal  40606647       34      19896         False
# 19  practice    normal  40606669       34      19865         False
# 20  practice    normal  40606690       33      17973         False
# 21  practice    normal  40606709       33      18555         False
# 22  practice    normal  40606729       34      19795         False
# 23  practice    normal  40606750       34      19896         False
# 24  practice    normal  40606771       34      21060         False
# 25  practice    normal  40606793       33      18423         False
# 26  practice    normal  40606813       35      21879         False
# 27  practice    normal  40606836       34      19896         False
# 28  practice    normal  40606858       34      19844         False
# 29  practice    normal  40606879       33      18292         False
# 30  practice    normal  40606898       34      20007         False
# 31  practice    normal  40606920       34      19683         False
# 32  practice    normal  40606941       33      18115         False
# 33  practice    normal  40606960       33      18259         False
# 34  practice    normal  40606979       34      19741         False
# 35  practice    normal  40607000       33      18368         False
# 36  practice    normal  40607020       33      18379         False
# 37  practice    normal  40607040       34      19507         False
# 38  practice    normal  40607061       33      18559         False
# 39  practice    normal  40607080       33      18395         False
# 40  practice    normal  40607100       34      19531         False
# 41  practice    normal  40607121       34      19643         False
# 42  practice    normal  40607142       33      18161         False
# 43  practice    normal  40607161       35      21445         False
# 44  practice    normal  40607184       33      17891         False
# 45  practice    normal  40607203       33      18259         False
# 46  practice    normal  40607222       34      19784         False
# 47  practice    normal  40607244       34      19765         False
# 48  practice    normal  40607265       34      19824         False
# 49  practice    normal  40607286       33      18190         False

# %%
counts = df.Guesses.value_counts()
total = counts.sum()
freqs = counts / total

fig, ax = plt.subplots()
p = ax.bar(counts.index, counts)
ax.bar_label(p, [f"{f * 100:.4}%" for f in freqs])
ax.set_xticks(sorted(counts.index))
ax.set_xlabel("Guesses")
ax.set_ylabel("Frequency")
ax.set_title("Distribution of Guesses")
fig.savefig("guesses-dist.png")
plt.show()

# %%
from matplotlib.ticker import PercentFormatter

times = df["Time (ms)"] / 1000.0

fig, ax = plt.subplots()
n, bins, p = ax.hist(times, bins=np.arange(17, 23), weights=np.ones_like(times) * 100 / len(times))
ax.bar_label(p, [f"{f * 100:.4}%" for f in n / n.sum()])
ax.set_xlabel("Time (s)")
ax.set_ylabel("Frequency")
ax.set_title("Distribution of Solve Times")
fig.savefig("times-dist.png")
plt.show()
